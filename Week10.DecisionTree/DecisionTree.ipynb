# %% [markdown]
# #EX5
# Dùng code xây dựng model cho data, https://github.com/nttuan8/DL_Tutorial/blob/master/L2/dataset.csv, vẽ đường decision boundary tương ứng.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/Machine_Learning_DSEB/Machine-Learning-with-Python/Week10.DecisionTree/dataset.csv')
df.head()
# Out:
#    Lương  Thời gian làm việc  Cho vay
# 0     10                 1.0        1
# 1      5                 2.0        1
# 2      6                 1.8        1
# 3      7                 1.0        1
# 4      8                 2.0        1
